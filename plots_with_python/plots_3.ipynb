# %% [markdown]
# # Plots 3

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
from feynman import Diagram
from feynman import Line
import numpy as np
class Theme:
    theme = "light"
    @staticmethod
    def set(_theme):
        Theme.theme = _theme
        if(Theme.theme == "dark"):
            plt.style.use('dark_background')
        else:
            plt.style.use('default')
        plt.rcParams['font.family'] = 'serif'
        plt.rcParams['font.serif'] = ['cmr10']  # Основной шрифт для текста
        plt.rcParams['mathtext.fontset'] = 'cm'
    @staticmethod
    def color():
        if(Theme.theme == "light"):
            return "black"
        else:
            return "white"
    @staticmethod
    def back():
        if(Theme.theme == "light"):
            return "white"
        else:
            return "black"
    @staticmethod
    def suff():
        if(Theme.theme == "light"):
            return "l"
        else:
            return "d"
        
def make_arrow(x,y,dx,dy,h,l):
    n = np.array([dx,dy])
    n = n/np.linalg.norm(n)

    p = np.array([-dy,dx])
    p = p/np.linalg.norm(p)

    X = np.array((x,y))

    return [ X +p*h/2, X-p*h/2, X + n*l ]

# %%
Theme.set("light")
#Theme.set("dark")
main_color = Theme.color()
style_params = {"color": main_color}
arrow_params = {"color": main_color,"width":0.02,"length":0.05}
fig = plt.figure(figsize=(3*2.4,2.4))
ax = fig.add_axes([0,0,1,1 ], frameon=False)
diagram = Diagram(ax)

ax.set_xlim(0, 3*0.4)
ax.set_ylim(0, 0.4)

H = 0.4
W = 0.4

###############
V_x = diagram.vertex(xy=(W/2-0.02, H-0.04), **style_params,markersize=6)
V_y = diagram.vertex(xy=(W/2+0.02, H-0.04), **style_params,markersize=6)

V_x1 = diagram.vertex(xy=(0.05, 0.04), marker='', **style_params)
V_x2 = diagram.vertex(xy=(W-0.05, 0.04), marker='', **style_params)

diagram.line(V_x,V_x1, **style_params,linewidth=2, arrow_param=arrow_params,arrow=False)
diagram.line(V_y,V_x2, **style_params,linewidth=2,arrow_param=arrow_params,arrow=False)


diagram.text(V_x.xy[0]-0.04, V_x.xy[1]+0.01, r"$x$", fontsize=32)
diagram.text(V_y.xy[0]+0.04, V_y.xy[1]+0.01, r"$y$", fontsize=32)


diagram.text(V_x1.xy[0]+0.05, V_x1.xy[1]+0.01, r"$x_1$", fontsize=32)
diagram.text(V_x2.xy[0]-0.05, V_x2.xy[1]+0.01, r"$x_2$", fontsize=32)

############

U_x = diagram.vertex(xy=(W+W/2-0.02, H-0.04), **style_params,markersize=6)
U_y = diagram.vertex(xy=(W+W/2+0.02, H-0.04), **style_params,markersize=6)

U_x1 = diagram.vertex(xy=(W+0.05, 0.04), marker='', **style_params)
U_x2 = diagram.vertex(xy=(W+W-0.05, 0.04), marker='', **style_params)

diagram.line(U_x,U_x2, **style_params,linewidth=2, arrow_param=arrow_params,arrow=False)
diagram.line(U_y,U_x1, **style_params,linewidth=2,arrow_param=arrow_params,arrow=False)


diagram.text(U_x.xy[0]-0.04, U_x.xy[1]+0.01, r"$x$", fontsize=32)
diagram.text(U_y.xy[0]+0.04, U_y.xy[1]+0.01, r"$y$", fontsize=32)

diagram.text(U_x1.xy[0]+0.05, U_x1.xy[1]+0.01, r"$x_1$", fontsize=32)
diagram.text(U_x2.xy[0]-0.05, U_x2.xy[1]+0.01, r"$x_2$", fontsize=32)

###########

# add arrow to ax

diagram.text(2*W, H/2, r"$\Longrightarrow$", fontsize=32)

###########

W_y = diagram.vertex(xy=(2*W+W/2, H-0.04), **style_params,markersize=12)

W_x1 = diagram.vertex(xy=(2*W+0.05, 0.04), marker='', **style_params)
W_x2 = diagram.vertex(xy=(2*W+W-0.05, 0.04), marker='', **style_params)

diagram.line(W_y,W_x2, **style_params,linewidth=2, arrow_param=arrow_params,arrow=False)
diagram.line(W_y,W_x1, **style_params,linewidth=2,arrow_param=arrow_params,arrow=False)

diagram.text(W_y.xy[0]+0.04, W_y.xy[1]+0.01, r"$y$", fontsize=32)

diagram.text(W_x1.xy[0]+0.05, W_x1.xy[1]+0.01, r"$x_1$", fontsize=32)
diagram.text(W_x2.xy[0]-0.05, W_x2.xy[1]+0.01, r"$x_2$", fontsize=32)

diagram.plot()


fig.savefig(f'../docs/DeepInelastic/OPE/images/OPE_phiphi-{Theme.suff()}.svg',transparent=True)

# %%
#Theme.set("light")
Theme.set("dark")
main_color = Theme.color()
style_params = {"color": main_color}
arrow_params = {"color": main_color,"width":0.02,"length":0.05}
fig = plt.figure(figsize=(3*2.4,2.4))
ax = fig.add_axes([0,0,1,1 ], frameon=False)
diagram = Diagram(ax)

ax.set_xlim(0, 3*0.4)
ax.set_ylim(0, 0.4)

H = 0.4
W = 0.4

###############
V_x = diagram.vertex(xy=(W/2-0.02, H-0.04), **style_params,markersize=6)
V_y = diagram.vertex(xy=(W/2+0.02, H-0.04), **style_params,markersize=6)

V_x1 = diagram.vertex(xy=(0.05, 0.04), marker='', **style_params)
V_x2 = diagram.vertex(xy=(W-0.05, 0.04), marker='', **style_params)

V_center = diagram.vertex(xy=(W/2, H/2), **style_params,markersize=6)


diagram.line(V_center,V_x, **style_params,linewidth=2,shape = 'elliptic', ellipse_excentricity = 1.4,arrow_param=arrow_params)
diagram.line(V_y,V_center, **style_params,linewidth=2,shape = 'elliptic', ellipse_excentricity = +1.4,arrow_param=arrow_params)

diagram.line(V_x1,V_center, **style_params,linewidth=2, arrow_param=arrow_params)
diagram.line(V_x2,V_center, **style_params,linewidth=2,arrow_param=arrow_params)


diagram.text(V_x.xy[0]-0.05, V_x.xy[1]+0.01, r"$x$", fontsize=32)
diagram.text(V_y.xy[0]+0.05, V_y.xy[1]+0.01, r"$y$", fontsize=32)

diagram.text(V_x1.xy[0]+0.05, V_x1.xy[1]+0.01, r"$x_1$", fontsize=32)
diagram.text(V_x2.xy[0]-0.05, V_x2.xy[1]+0.01, r"$x_2$", fontsize=32)

diagram.text(W/2-0.13, H/2-0.06, r"$p_1$", fontsize=32)
diagram.text(W/2+0.13, H/2-0.06, r"$p_2$", fontsize=32)

diagram.text(W/2-0.11, H/2+0.08, r"$q$", fontsize=32)
diagram.text(W/2+0.11, H/2+0.08, r"$p$", fontsize=32)

# add arrow to ax

diagram.text(W, H/2, r"$\Longrightarrow$", fontsize=32)

###########

W_y = diagram.vertex(xy=(W+W/2, H-0.04), **style_params,markersize=12)

W_x1 = diagram.vertex(xy=(W+0.05, 0.04), marker='', **style_params)
W_x2 = diagram.vertex(xy=(W+W-0.05, 0.04), marker='', **style_params)

W_center = diagram.vertex(xy=(W + W/2, H/2), **style_params,markersize=6)

diagram.line(W_center,W_y, **style_params,linewidth=2,shape = 'elliptic', ellipse_excentricity = 1.4,arrow_param=arrow_params)
diagram.line(W_y,W_center, **style_params,linewidth=2,shape = 'elliptic', ellipse_excentricity = +1.4,arrow_param=arrow_params)

diagram.line(W_x1,W_center, **style_params,linewidth=2, arrow_param=arrow_params)
diagram.line(W_x2,W_center, **style_params,linewidth=2,arrow_param=arrow_params)


diagram.text(W_y.xy[0]+0.06, W_y.xy[1]+0.01, r"$y$", fontsize=32)

diagram.text(W_x1.xy[0]+0.05, W_x1.xy[1]+0.01, r"$x_1$", fontsize=32)
diagram.text(W_x2.xy[0]-0.05, W_x2.xy[1]+0.01, r"$x_2$", fontsize=32)

## Counterterm ###########

diagram.text(2*W, H/2, r"$+$", fontsize=42)

W1_y = diagram.vertex(xy=(2*W+W/2, H-0.04), marker='x', **style_params,markersize=20)

W1_x1 = diagram.vertex(xy=(2*W+0.05, 0.04), marker='', **style_params)
W1_x2 = diagram.vertex(xy=(2*W+W-0.05, 0.04), marker='', **style_params)

diagram.line(W1_y,W1_x2, **style_params,linewidth=2, arrow_param=arrow_params,arrow=False)
diagram.line(W1_y,W1_x1, **style_params,linewidth=2,arrow_param=arrow_params,arrow=False)

diagram.text(W1_y.xy[0]+0.06, W1_y.xy[1]+0.01, r"$y$", fontsize=32)

diagram.text(W1_x1.xy[0]+0.05, W1_x1.xy[1]+0.01, r"$x_1$", fontsize=32)
diagram.text(W1_x2.xy[0]-0.05, W1_x2.xy[1]+0.01, r"$x_2$", fontsize=32)

diagram.plot()




fig.savefig(f'../docs/DeepInelastic/OPE/images/OPE_phiphi-lambda-{Theme.suff()}.svg',transparent=True)

# %%
Theme.set("light")
#Theme.set("dark")
main_color = Theme.color()
style_params = {"color": main_color}
arrow_params = {"color": main_color,"width":0.02,"length":0.05}
fig = plt.figure(figsize=(3*2.4,2.4))
ax = fig.add_axes([0,0,1,1 ], frameon=False)
diagram = Diagram(ax)

ax.set_xlim(0, 3*0.4)
ax.set_ylim(0, 0.4)


H = 0.4

W_shift = 0.15

diagram.text( 0.09, H/2, r"$\int {\; \operatorname{d}\! \Pi_X}$", fontsize=24)

in1_L = diagram.vertex(xy=(W_shift+ 0.05, H-0.08), marker='', **style_params)
in2_L = diagram.vertex(xy=(W_shift +0.05, 0.08), marker='', **style_params)


diagram.text( in1_L.xy[0]+0.05, in1_L.xy[1]+0.01, r"$e^{\!\!\!-}$", fontsize=32)
diagram.text( in2_L.xy[0]+0.05, in2_L.xy[1]-0.01, r"$e^{\!\!\!+}$", fontsize=32)

Module_ld = diagram.vertex(xy=(in2_L.xy[0]-0.02, 0.03), marker='', **style_params)
Module_lu = diagram.vertex(xy=(in2_L.xy[0]-0.02, H-0.03), marker='', **style_params)
diagram.line(Module_ld,Module_lu, **style_params,linewidth=1.5, arrow_param=arrow_params,arrow=False)

Module_rd = diagram.vertex(xy=(W_shift+0.34+0.02, 0.03), marker='', **style_params)
Module_ru = diagram.vertex(xy=(W_shift+0.34+0.02, H-0.03), marker='', **style_params)
diagram.line(Module_rd,Module_ru, **style_params,linewidth=1.5, arrow_param=arrow_params,arrow=False)
diagram.text( Module_ru.xy[0]+0.03, Module_ru.xy[1]-0.01, r"$2$", fontsize=26)


center1_L = diagram.vertex(xy=(W_shift+0.12, 0.2), **style_params,markersize=4)
center2_L = diagram.vertex(xy=(W_shift+0.26, 0.2),**style_params,markersize=4)

diagram.line(in1_L,center1_L, **style_params,linewidth=2, arrow_param=arrow_params)
diagram.line(center1_L, in2_L,**style_params,linewidth=2, arrow_param=arrow_params)
diagram.line(center1_L,center2_L, **style_params,linewidth=2, style='wiggly',nwiggles = 3)

vs = [diagram.vertex(xy=(W_shift+0.34,H/2 + 0.03*i), marker='', **style_params) for i in range(-3,4)]
for v in vs:
    diagram.line(center2_L,v, **style_params,linewidth=1.5, arrow_param=arrow_params,arrow=False) 

diagram.text( W_shift+0.3, H-0.1, r"$X$", fontsize=26)


diagram.text( W_shift+0.46, H/2, r"$=2\operatorname{Im}$", fontsize=26)



W_center = 0.94
W = 0.24


in_1 = diagram.vertex(xy=(W_center-W, H-0.08), marker='', **style_params)
in_2 = diagram.vertex(xy=(W_center-W, 0.08), marker='', **style_params)



diagram.text( in_1.xy[0]+0.05, in_1.xy[1]+0.01, r"$e^{\!\!\!-}$", fontsize=32)
diagram.text( in_2.xy[0]+0.05, in_2.xy[1]-0.01, r"$e^{\!\!\!+}$", fontsize=32)

center_1 = diagram.vertex(xy=(W_center-2*W/3, 0.2), **style_params,markersize=4)
center_2 = diagram.vertex(xy=(W_center+2*W/3, 0.2),**style_params,markersize=4)

center_3 = diagram.vertex(xy=(W_center-W/6, 0.2),**style_params,markersize=4)
center_4 = diagram.vertex(xy=(W_center+W/6, 0.2),**style_params,markersize=4)

out_1 = diagram.vertex(xy=(W_center+W, H-0.08), marker='', **style_params)
out_2 = diagram.vertex(xy=(W_center+W, 0.08), marker='', **style_params)



diagram.text( out_1.xy[0]-0.05, out_1.xy[1]+0.01, r"$e^{\!\!\!-}$", fontsize=32)
diagram.text( out_2.xy[0]-0.05, out_2.xy[1]-0.01, r"$e^{\!\!\!+}$", fontsize=32)

diagram.line(in_1,center_1, **style_params,linewidth=2, arrow_param=arrow_params)
diagram.line(center_1, in_2,**style_params,linewidth=2, arrow_param=arrow_params)

diagram.line(center_1,center_3, **style_params,linewidth=2, style='wiggly',nwiggles = 3)
diagram.line(center_2,center_4, **style_params,linewidth=2, style='wiggly',nwiggles = 3)
ax.add_patch(
    mpl.patches.Circle(
        (W_center, H / 2),
        0.04,
        edgecolor=main_color,
        facecolor=mpl.colors.to_rgba(main_color, alpha=0.5),
        linewidth=1.5,
    )
)

diagram.line(center_2,out_1, **style_params,linewidth=2, arrow_param=arrow_params)
diagram.line(center_2,out_2, **style_params,linewidth=2, arrow_param=arrow_params)

diagram.plot()

#fig.savefig(f'../docs/DeepInelastic/OPE/images/OPE_OpticalTheorem-{Theme.suff()}.svg',transparent=True)

# %%
#Theme.set("light")
Theme.set("dark")
main_color = Theme.color()
style_params = {"color": main_color}

def color_alpha(alpha):
    return mpl.colors.to_rgba(main_color, alpha=alpha)

arrow_params = {"color": main_color,"width":0.02,"length":0.05}
fig = plt.figure(figsize=(3*2.4,2.4))
ax = fig.add_axes([0,0,1,1 ], frameon=False)
diagram = Diagram(ax)

ax.set_xlim(0, 3*0.4)
ax.set_ylim(0, 0.4)


H = 0.4
W = 0.4

ope_x_1 = diagram.vertex((W/2-0.1,H/2), **style_params,markersize=4)
ope_y_1 = diagram.vertex((W/2+0.1,H/2), **style_params,markersize=4)

diagram.line(ope_x_1, ope_y_1, **style_params,shape = 'elliptic', ellipse_excentricity = 1,
             linewidth=2, arrow_param=arrow_params)
diagram.line( ope_y_1,ope_x_1, **style_params,shape = 'elliptic', ellipse_excentricity = 1,
             linewidth=2, arrow_param=arrow_params)

sqr2=0.5**0.5
gin_1 = diagram.vertex( xy = (W/2 -0.1*sqr2,H/2 + 0.1*sqr2), marker='', markersize=12, **style_params)
gout_1 = diagram.vertex( xy = (W/2 -0.1*sqr2,H/2 - 0.1*sqr2), marker='', markersize=12, **style_params)

lineG_1 = Line(
    gin_1, gout_1,color = color_alpha(0.5) ,
    style='loopy', linewidth=2, nloops=4,shape="elliptic",
    ellipse_excentricity = 1.2,
    phase=0,xamp=0.02,yamp=-0.02,
    arrow_param=arrow_params)
diagram.add_line(lineG_1)

gin_1_r = diagram.vertex( xy = (W/2 +0.1*sqr2,H/2 + 0.1*sqr2), marker='', markersize=12, **style_params)
gout_1_r = diagram.vertex( xy = (W/2 +0.1*sqr2,H/2 - 0.1*sqr2), marker='', markersize=12, **style_params)

lineG_1 = Line(
    gin_1_r, gout_1_r,color = color_alpha(0.5) ,
    style='loopy', linewidth=2, nloops=4,shape="elliptic",
    ellipse_excentricity = -1.2,
    phase=0,xamp=0.02,yamp=0.02,
    arrow_param=arrow_params)
diagram.add_line(lineG_1)



diagram.text(ope_x_1.xy[0]-0.04, ope_x_1.xy[1], r"$x$", fontsize=32)
diagram.text(ope_y_1.xy[0]+0.04, ope_y_1.xy[1], r"$0$", fontsize=32)

########

ope_x_2 = diagram.vertex((W + W/2-0.1,H/2), **style_params,markersize=4)
ope_y_2 = diagram.vertex((W + W/2+0.1,H/2), **style_params,markersize=4)

diagram.line( ope_y_2,ope_x_2, **style_params,shape = 'elliptic', ellipse_excentricity = 1,
             linewidth=2, arrow_param=arrow_params)
diagram.text(ope_x_2.xy[0]-0.04, ope_x_1.xy[1], r"$x$", fontsize=32)
diagram.text(ope_y_2.xy[0]+0.04, ope_y_1.xy[1], r"$0$", fontsize=32)

outq_1 = diagram.vertex( xy = (W + W/2 -0.1, H/2 + 0.15), marker='', **style_params)
outq_2 = diagram.vertex( xy = (W + W/2 + 0.1, H/2 + 0.15), marker='', **style_params)

diagram.line(ope_x_2, outq_1, **style_params,linewidth=2, arrow_param=arrow_params)
diagram.line(ope_y_2, outq_2, **style_params,linewidth=2, arrow_param=arrow_params)

###

ope_x_3 = diagram.vertex((2*W + W/2-0.1,H/2), **style_params,markersize=4)
ope_y_3 = diagram.vertex((2*W + W/2+0.1,H/2), **style_params,markersize=4)

diagram.line( ope_x_3,ope_y_3, **style_params,shape = 'elliptic', ellipse_excentricity = 1,
             linewidth=2, arrow_param=arrow_params)
diagram.line( ope_y_3,ope_x_3, **style_params,shape = 'elliptic', ellipse_excentricity = 1,
             linewidth=2, arrow_param=arrow_params)

diagram.text(ope_x_3.xy[0]-0.04, ope_x_1.xy[1], r"$x$", fontsize=32)
diagram.text(ope_y_3.xy[0]+0.04, ope_y_1.xy[1], r"$0$", fontsize=32)

signs = [-1,1]

gloun_ins = [
    diagram.vertex( xy = (2*W + W/2 + i*0.1*sqr2, H/2 + j*0.1*sqr2), marker='', 
                   markersize=12, **style_params) for i in signs for j in signs]
gluon_outs = [
    diagram.vertex( xy = (2*W + W/2 + i*0.24*sqr2, H/2 + j*0.24*sqr2), marker='', 
                   markersize=12, **style_params) for i in signs for j in signs]

for i, gin, gout in zip([1,-1,-1,1],gloun_ins, gluon_outs):
    lineG = Line(
        gin, gout,color = color_alpha(1) ,
        style='loopy', linewidth=2, nloops=4,
        phase=0,xamp=0.02,yamp=i*0.02,
        arrow_param=arrow_params)
    diagram.add_line(lineG)

diagram.plot()

fig.savefig(f'../docs/DeepInelastic/OPE/images/OPE_JJ_Diagrams-{Theme.suff()}.svg',transparent=True)

# %%
from matplotlib.patches import Arc

Theme.set("light")
#Theme.set("dark")
main_color = Theme.color()
style_params = {"color": main_color}

def color_alpha(alpha):
    return mpl.colors.to_rgba(main_color, alpha=alpha)

arrow_params = {"color": main_color,"width":0.02,"length":0.05}
fig = plt.figure(figsize=(1.5*2.4,2.4))
ax = fig.add_axes([0,0,1,1 ], frameon=False)
diagram = Diagram(ax)


ax.set_xlim(0, 1.5*0.4)
ax.set_ylim(0, 0.4)
H=0.4

x_saw = np.linspace(0.35,0.58,16,endpoint=True)
y_saw = np.array([H/2]+[H/2-0.015 if i%2==0 else H/2+0.015 for i in range(len(x_saw)-1)])


ax.add_line(mpl.lines.Line2D([0.05, 0.35], [H/2,H/2], linewidth=1.5,color= main_color))
ax.add_line(mpl.lines.Line2D([0.25, 0.25], [0.05,H-0.05], linewidth=1.5,color= main_color))

ax.plot(x_saw, y_saw, linewidth=1.5,color=color_alpha(1))

ax.scatter([0.35],[H/2],color=color_alpha(1))

ax.scatter([0.12],[H/2],color=color_alpha(1))


diagram.text(0.12,H/2-0.05,r"$-Q_0^2$",color=color_alpha(1),fontsize=20)

IntCountur = []

arc = Arc((0.35, H/2), 0.06, 0.06, theta1=90, theta2=-90,linestyle='--', linewidth=1.2,color= main_color)
ax.add_patch(arc)

ax.add_line(mpl.lines.Line2D([0.35, 0.57], [H/2+0.03,H/2+0.03],linestyle='--', linewidth=1.2,color= main_color))
ax.add_line(mpl.lines.Line2D([0.35, 0.57], [H/2-0.03,H/2-0.03],linestyle='--', linewidth=1.2,color= main_color))


ax.add_line(mpl.lines.Line2D([0.57,0.2], [H-0.02,H-0.02],linestyle='--', linewidth=1.2,color= main_color))
ax.add_line(mpl.lines.Line2D([0.57,0.2], [0.02,0.02],linestyle='--', linewidth=1.2,color= main_color))



arc = Arc((0.2, H/2), 0.36, 0.36, theta1=90, theta2=-90,linestyle='--', linewidth=1.2)
ax.add_patch(arc)

from matplotlib.patches import Polygon
arrow = Polygon(make_arrow(0.4,H-0.02,-1,0,0.016,0.02),color= main_color)
ax.add_patch(arrow)

arrow = Polygon(make_arrow(0.4,0.02,1,0,0.016,0.02),color= main_color)
ax.add_patch(arrow)

arrow = Polygon(make_arrow(0.45,H/2+0.03,1,0,0.016,0.02),color= main_color)
ax.add_patch(arrow)

arrow = Polygon(make_arrow(0.45,H/2-0.03,-1,0,0.016,0.02),color= main_color)
ax.add_patch(arrow)

plt.show()

fig.savefig(f'../docs/DeepInelastic/OPE/images/OPE_JJ_complplane-{Theme.suff()}.svg',transparent=True)

# %%
from matplotlib.patches import Arc

#Theme.set("light")
Theme.set("dark")
main_color = Theme.color()
style_params = {"color": main_color}

def color_alpha(alpha):
    return mpl.colors.to_rgba(main_color, alpha=alpha)

arrow_params = {"color": main_color,"width":0.02,"length":0.05}
fig = plt.figure(figsize=(1.5*2.4,2.4))
ax = fig.add_axes([0,0,1,1 ], frameon=False)
diagram = Diagram(ax)


ax.set_xlim(0, 1.5*0.4)
ax.set_ylim(0, 0.4)
H=0.4

x_saw = np.linspace(0.2,0.4,15,endpoint=True)
y_saw = np.array([H/2]+[H/2-0.015 if i%2==0 else H/2+0.015 for i in range(len(x_saw)-2)] + [H/2])


ax.add_line(mpl.lines.Line2D([0.05, 0.2], [H/2,H/2], linewidth=1.5,color= main_color))
ax.add_line(mpl.lines.Line2D([0.4, 0.55], [H/2,H/2], linewidth=1.5,color= main_color))
ax.add_line(mpl.lines.Line2D([0.3, 0.3], [0.05,H-0.05], linewidth=1.5,color= main_color))

ax.plot(x_saw, y_saw, linewidth=1.5,color=color_alpha(1))

ax.scatter([0.2],[H/2],color=color_alpha(1))
ax.scatter([0.4],[H/2],color=color_alpha(1))


diagram.text(0.16,H/2-0.06,r"$-1$",color=color_alpha(1),fontsize=20)
diagram.text(0.4,H/2-0.06,r"$1$",color=color_alpha(1),fontsize=20)

IntCountur = []

arc = Arc((0.2, H/2), 0.06, 0.06, theta1=90, theta2=-90,linestyle='--', linewidth=1.2,color= main_color)
ax.add_patch(arc)

arc = Arc((0.4, H/2), 0.06, 0.06, theta1=-90, theta2=90,linestyle='--', linewidth=1.2,color= main_color)
ax.add_patch(arc)

ax.add_line(mpl.lines.Line2D([0.2, 0.4], [H/2+0.03,H/2+0.03],linestyle='--', linewidth=1.2,color= main_color))
ax.add_line(mpl.lines.Line2D([0.4, 0.2], [H/2-0.03,H/2-0.03],linestyle='--', linewidth=1.2,color= main_color))



from matplotlib.patches import Polygon

arrow = Polygon(make_arrow(0.25,H/2+0.03,-1,0,0.016,0.02),color= main_color)
ax.add_patch(arrow)

arrow = Polygon(make_arrow(0.35,H/2-0.03,1,0,0.016,0.02),color= main_color)
ax.add_patch(arrow)

plt.show()

fig.savefig(f'../docs/DeepInelastic/OPE/images/OPE_JJpp_complplane-{Theme.suff()}.svg',transparent=True)

# %%
Theme.set("light")
#Theme.set("dark")
main_color = Theme.color()
style_params = {"color": main_color}
arrow_params = {"color": main_color,"width":0.02,"length":0.05}
fig = plt.figure(figsize=(3*2.4,2.4))
ax = fig.add_axes([0,0,1,1 ], frameon=False)
diagram = Diagram(ax)

ax.set_xlim(0, 3*0.4)
ax.set_ylim(0, 0.4)

H = 0.4
W = 0.4

###############
 
V_x1 = diagram.vertex(xy=(0.05, 0.04), marker='', **style_params)
V_x2 = diagram.vertex(xy=(W-0.05, 0.04), marker='', **style_params)


V_center = diagram.vertex(xy=(W/2, H-0.04), **style_params,markersize=6)

V_y1 = diagram.vertex(xy=V_x1.xy*0.5+V_center.xy*0.5, **style_params,marker='')
V_y2 = diagram.vertex(xy=V_x2.xy*0.5+V_center.xy*0.5, **style_params,marker='')


diagram.line(V_x1,V_y1, **style_params,linewidth=2, arrow_param=arrow_params)
diagram.line(V_y2,V_x2, **style_params,linewidth=2,arrow_param=arrow_params)

diagram.line(V_y1,V_center, **style_params,linewidth=2, arrow_param=arrow_params)
diagram.line(V_center,V_y2, **style_params,linewidth=2,arrow_param=arrow_params)

diagram.line(V_y1,V_y2, **style_params,linewidth=2,style='loopy',  nloops=4,
        phase=0.,xamp=0.02,yamp=-0.02)


diagram.text(V_x1.xy[0]+0.05, V_x1.xy[1]+0.01, r"$p$", fontsize=32)
diagram.text(V_x2.xy[0]-0.06, V_x2.xy[1]+0.01, r"$p'$", fontsize=32)

# add arrow to ax

diagram.text(W, H/2, r"$+$", fontsize=32)

###########

V_center = diagram.vertex(xy=(W + W/2, H-0.04), **style_params,markersize=6)
V_x1 = diagram.vertex(xy=(W+0.05, 0.04), marker='', **style_params)
V_x2 = diagram.vertex(xy=(W+W-0.05, 0.04), marker='', **style_params)

V_y1 = diagram.vertex(xy=V_x1.xy*0.5+V_center.xy*0.5, **style_params,marker='')
V_y2 = diagram.vertex(xy=V_x2.xy*0.5+V_center.xy*0.5, **style_params,marker='')



diagram.line(V_x1,V_y1, **style_params,linewidth=2, arrow_param=arrow_params)
diagram.line(V_center,V_x2, **style_params,linewidth=2,arrow_param=arrow_params)

diagram.line(V_y1,V_center, **style_params,linewidth=2, arrow_param=arrow_params)
#diagram.line(V_center,V_y2, **style_params,linewidth=2,arrow_param=arrow_params)

diagram.line(V_center,V_y1, **style_params,linewidth=2,style='loopy',  nloops=5,
        phase=0.,xamp=0.02,yamp=0.02, shape='elliptic', ellipse_excentricity = -1.1)

diagram.text(V_x1.xy[0]+0.05, V_x1.xy[1]+0.01, r"$p$", fontsize=32)
diagram.text(V_x2.xy[0]-0.06, V_x2.xy[1]+0.01, r"$p'$", fontsize=32)


## Counterterm ###########

diagram.text(2*W, H/2, r"$+$", fontsize=32)

V_center = diagram.vertex(xy=(2*W + W/2, H-0.04), **style_params,markersize=6)
V_x1 = diagram.vertex(xy=(2*W+0.05, 0.04), marker='', **style_params)
V_x2 = diagram.vertex(xy=(2*W+W-0.05, 0.04), marker='', **style_params)

V_y1 = diagram.vertex(xy=V_x1.xy*0.5+V_center.xy*0.5, **style_params,marker='')
V_y2 = diagram.vertex(xy=V_x2.xy*0.5+V_center.xy*0.5, **style_params,marker='')



diagram.line(V_x1,V_center, **style_params,linewidth=2, arrow_param=arrow_params)
diagram.line(V_y2,V_x2, **style_params,linewidth=2,arrow_param=arrow_params)

#diagram.line(V_y1,V_center, **style_params,linewidth=2, arrow_param=arrow_params)
diagram.line(V_center,V_y2, **style_params,linewidth=2,arrow_param=arrow_params)

diagram.line(V_center,V_y2, **style_params,linewidth=2,style='loopy',  nloops=5,
        phase=0.,xamp=0.02,yamp=-0.02, shape='elliptic', ellipse_excentricity = 1.1)


diagram.text(V_x1.xy[0]+0.05, V_x1.xy[1]+0.01, r"$p$", fontsize=32)
diagram.text(V_x2.xy[0]-0.06, V_x2.xy[1]+0.01, r"$p'$", fontsize=32)


diagram.plot()




fig.savefig(f'../docs/DeepInelastic/OPE/images/OPE_JJ-renorm-ff-{Theme.suff()}.svg',transparent=True)

# %%
Theme.set("light")
#Theme.set("dark")
main_color = Theme.color()
style_params = {"color": main_color}
arrow_params = {"color": main_color,"width":0.02,"length":0.05}
fig = plt.figure(figsize=(3*2.4,2.4))
ax = fig.add_axes([0,0,1,1 ], frameon=False)
diagram = Diagram(ax)

ax.set_xlim(0, 3*0.4)
ax.set_ylim(0, 0.4)

H = 0.4
W = 0.4

###############
 
V_x1 = diagram.vertex(xy=(0.05, 0.04), marker='', **style_params)
V_x2 = diagram.vertex(xy=(W-0.05, 0.04), marker='', **style_params)


V_center = diagram.vertex(xy=(W/2, H-0.04), **style_params,markersize=6)

V_y1 = diagram.vertex(xy=(V_x1.xy[0],V_x1.xy[1]*0.5+V_center.xy[1]*0.5), **style_params,marker='')
V_y2 = diagram.vertex(xy=(V_x2.xy[0],V_x2.xy[1]*0.5+V_center.xy[1]*0.5), **style_params,marker='')

diagram.line(V_x1,V_y1, **style_params,linewidth=2, style='wiggly',  nwiggles=3)
diagram.line(V_y2,V_x2, **style_params,linewidth=2, style='wiggly',  nwiggles=3)

diagram.line(V_y1,V_center, **style_params,linewidth=2, arrow_param=arrow_params)
diagram.line(V_center,V_y2, **style_params,linewidth=2,arrow_param=arrow_params)

diagram.line(V_y1,V_y2, **style_params,linewidth=2,arrow_param=arrow_params)


diagram.text(V_x1.xy[0]+0.05, V_x1.xy[1]+0.01, r"$p$", fontsize=32)
diagram.text(V_x2.xy[0]-0.06, V_x2.xy[1]+0.01, r"$p'$", fontsize=32)

# add arrow to ax


###########

V_center = diagram.vertex(xy=(W + W/2, H-0.04), **style_params,markersize=6)
V_x1 = diagram.vertex(xy=(W+0.05, 0.04), marker='', **style_params)
V_x2 = diagram.vertex(xy=(W+W-0.05, 0.04), marker='', **style_params)

V_y1 = diagram.vertex(xy=(V_x1.xy[0],V_x1.xy[1]*0.5+V_center.xy[1]*0.5), **style_params,marker='')
V_y2 = diagram.vertex(xy=(V_x2.xy[0],V_x2.xy[1]*0.5+V_center.xy[1]*0.5), **style_params,marker='')

diagram.line(V_x2,V_y1, **style_params,linewidth=2, style='wiggly',  nwiggles=5)
diagram.line(V_y2,V_x1, **style_params,linewidth=2, style='wiggly',  nwiggles=5)

diagram.line(V_y1,V_center, **style_params,linewidth=2, arrow_param=arrow_params)
diagram.line(V_center,V_y2, **style_params,linewidth=2,arrow_param=arrow_params)

diagram.line(V_y1,V_y2, **style_params,linewidth=2,arrow_param=arrow_params)



## Counterterm ###########


V_center = diagram.vertex(xy=(2*W + W/2, H-0.04), **style_params,markersize=6)
V_x1 = diagram.vertex(xy=(2*W+0.05, 0.04), marker='', **style_params)
V_x2 = diagram.vertex(xy=(2*W+W-0.05, 0.04), marker='', **style_params)

V_y1 = diagram.vertex(xy=(V_x1.xy[0],V_x1.xy[1]*0.5+V_center.xy[1]*0.5), **style_params,marker='')
V_y2 = diagram.vertex(xy=(V_x2.xy[0],V_x2.xy[1]*0.5+V_center.xy[1]*0.5), **style_params,marker='')

diagram.line(V_x1,V_y1, **style_params,linewidth=2,arrow_param=arrow_params)
diagram.line(V_y2,V_x2, **style_params,linewidth=2,arrow_param=arrow_params)

diagram.line(V_y1,V_center, **style_params,linewidth=2, style='wiggly',  nwiggles=4)
diagram.line(V_center,V_y2, **style_params,linewidth=2, style='wiggly',  nwiggles=4)

diagram.line(V_y1,V_y2, **style_params,linewidth=2, style='wiggly',  nwiggles=5)


diagram.text(V_x1.xy[0]+0.04, V_x1.xy[1]+0.01, r"$p$", fontsize=32)
diagram.text(V_x2.xy[0]-0.05, V_x2.xy[1]+0.01, r"$p'$", fontsize=32)


diagram.plot()




fig.savefig(f'../docs/DeepInelastic/OPE/images/OPE_JJ-renorm-fg-{Theme.suff()}.svg',transparent=True)

# %%
#Theme.set("light")
Theme.set("dark")
main_color = Theme.color()
style_params = {"color": main_color}
arrow_params = {"color": main_color,"width":0.02,"length":0.05}
fig = plt.figure(figsize=(3*2.4,2.4))
ax = fig.add_axes([0,0,1,1 ], frameon=False)
diagram = Diagram(ax)

ax.set_xlim(0, 3*0.4)
ax.set_ylim(0, 0.4)

H = 0.4
W = 0.4

###############
 
V_x1 = diagram.vertex(xy=(0.05, 0.04), marker='', **style_params)
V_x2 = diagram.vertex(xy=(W-0.05, 0.04), marker='', **style_params)


V_center = diagram.vertex(xy=(W/2, H-0.04), **style_params,markersize=6)

V_y1 = diagram.vertex(xy=V_x1.xy*0.5+V_center.xy*0.5, **style_params,marker='')
V_y2 = diagram.vertex(xy=V_x2.xy*0.5+V_center.xy*0.5, **style_params,marker='')


diagram.line(V_x1,V_y1, **style_params,linewidth=2, style='wiggly',  nwiggles=3)
diagram.line(V_y2,V_x2, **style_params,linewidth=2, style='wiggly',  nwiggles=3,phase=0.5)

diagram.line(V_y1,V_center, **style_params,linewidth=2, style='wiggly',  nwiggles=3)
diagram.line(V_center,V_y2, **style_params,linewidth=2, style='wiggly',  nwiggles=3,phase=0.5)

diagram.line(V_y1,V_y2, **style_params,linewidth=2, style='wiggly',  nwiggles=3,
        phase=0.,xamp=0.02,yamp=-0.02)


diagram.text(V_x1.xy[0]+0.05, V_x1.xy[1]+0.01, r"$p$", fontsize=32)
diagram.text(V_x2.xy[0]-0.06, V_x2.xy[1]+0.01, r"$p'$", fontsize=32)

# add arrow to ax

diagram.text(W, H/2, r"$+$", fontsize=32)

###########

V_center = diagram.vertex(xy=(W + W/2, H-0.04), **style_params,markersize=6)
V_x1 = diagram.vertex(xy=(W+0.05, 0.04), marker='', **style_params)
V_x2 = diagram.vertex(xy=(W+W-0.05, 0.04), marker='', **style_params)

V_y1 = diagram.vertex(xy=V_x1.xy*0.5+V_center.xy*0.5, **style_params,marker='')
V_y2 = diagram.vertex(xy=V_x2.xy*0.5+V_center.xy*0.5, **style_params,marker='')



diagram.line(V_x1,V_y1, **style_params,linewidth=2, style='wiggly',  nwiggles=3)
diagram.line(V_center,V_x2, **style_params,linewidth=2, style='wiggly',  nwiggles=6,phase=0.5)

diagram.line(V_y1,V_center, **style_params,linewidth=2, style='wiggly',  nwiggles=3)
#diagram.line(V_center,V_y2, **style_params,linewidth=2,arrow_param=arrow_params)

diagram.line(V_center,V_y1, **style_params,linewidth=2, style='wiggly',  nwiggles=5,
             phase=0.5, shape='elliptic', ellipse_excentricity = -1.2)

diagram.text(V_x1.xy[0]+0.05, V_x1.xy[1]+0.01, r"$p$", fontsize=32)
diagram.text(V_x2.xy[0]-0.06, V_x2.xy[1]+0.01, r"$p'$", fontsize=32)


## Counterterm ###########

diagram.text(2*W, H/2, r"$+$", fontsize=32)

V_center = diagram.vertex(xy=(2*W + W/2, H-0.04), **style_params,markersize=6)
V_x1 = diagram.vertex(xy=(2*W+0.05, 0.04), marker='', **style_params)
V_x2 = diagram.vertex(xy=(2*W+W-0.05, 0.04), marker='', **style_params)

V_y1 = diagram.vertex(xy=V_x1.xy*0.5+V_center.xy*0.5, **style_params,marker='')
V_y2 = diagram.vertex(xy=V_x2.xy*0.5+V_center.xy*0.5, **style_params,marker='')



diagram.line(V_x1,V_center, **style_params,linewidth=2, style='wiggly',  nwiggles=6)
diagram.line(V_x2,V_y2, **style_params,linewidth=2, style='wiggly',  nwiggles=3,phase=0.5)

#diagram.line(V_y1,V_center, **style_params,linewidth=2, arrow_param=arrow_params)
diagram.line(V_y2,V_center, **style_params,linewidth=2, style='wiggly',  nwiggles=3,phase=0.5)

diagram.line(V_center,V_y2, **style_params,linewidth=2,style='wiggly',  nwiggles=5,
              shape='elliptic', ellipse_excentricity = 1.2)


diagram.text(V_x1.xy[0]+0.05, V_x1.xy[1]+0.01, r"$p$", fontsize=32)
diagram.text(V_x2.xy[0]-0.06, V_x2.xy[1]+0.01, r"$p'$", fontsize=32)


diagram.plot()





fig.savefig(f'../docs/DeepInelastic/OPE/images/OPE_JJ-renorm-gg-{Theme.suff()}.svg',transparent=True)
